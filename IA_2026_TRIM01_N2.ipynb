# %%
import numpy as np
import pandas as pd

# %%
# Atividade 1
controle_estoque = pd.Series([150, 200, 120, 300, 250], 
index=["Segunda","Terça", "Quarta", "Quinta", "Sexta"])
print(controle_estoque)
# Out:
# Segunda    150
# Terça      200
# Quarta     120
# Quinta     300
# Sexta      250
# dtype: int64

# %%
# Atividade 2
filmes = {
    "Título": ["Kung Fu Panda", "Kung Fu Panda 2", "Kung Fu Panda 3", "Kung Fu Panda 4"],
    "Ano de Lançamento": [2008, 2011, 2016, 2024],
    "Gênero": ["Comédia e Ação", "Comédia e Ação", "Comédia e Ação", "Comédia e Ação"]
}

legal = pd.DataFrame(filmes)
legal
# Out:
#             Título  Ano de Lançamento          Gênero
# 0    Kung Fu Panda               2008  Comédia e Ação
# 1  Kung Fu Panda 2               2011  Comédia e Ação
# 2  Kung Fu Panda 3               2016  Comédia e Ação
# 3  Kung Fu Panda 4               2024  Comédia e Ação

# %%
# Atividade 3
legal["Título"]
# Out:
# 0      Kung Fu Panda
# 1    Kung Fu Panda 2
# 2    Kung Fu Panda 3
# 3    Kung Fu Panda 4
# Name: Título, dtype: str
